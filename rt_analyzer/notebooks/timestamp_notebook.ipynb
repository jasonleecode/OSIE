# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
f=open("/home/ivan/repos/nexedi/osie/rt_analyzer/channel0_duration.txt", "r")
lines = f.readlines()
f.close()
lines = [float(x.replace("\n", "")) for x  in lines[:]]

# %%
d = {}
i = 0
for x in lines:
    d[i] = x
    i += 1
s = pd.Series(d, name='duration')

# %%
s.plot.bar()
plt.title("Channel 0")
plt.show()

# %%
f=open("/home/ivan/repos/nexedi/osie/rt_analyzer/channel1_duration.txt", "r")
lines = f.readlines()
f.close()
lines = [float(x.replace("\n", "")) for x  in lines[:]]

# %%
d = {}
i = 0
for x in lines:
    d[i] = x
    i += 1
s = pd.Series(d, name='duration')

# %%
s.plot.bar()
plt.title("Channel 1")
plt.show()
